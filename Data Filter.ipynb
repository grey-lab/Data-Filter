# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/mosesgrey/Desktop/Dennis Bruce Contacts.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#                          Name First name     Last name  \
# 0                 Steve Caton      Steve         Caton
# 1             Jonathan Siskin   Jonathan        Siskin
# 2              Mike Carpenter       Mike     Carpenter
# 3             Benedict Dsilva   Benedict        Dsilva
# 4                 Laura Young      Laura         Young
# ..                        ...        ...           ...
# 889             Laura Carolyn      Laura       Carolyn
# 890             Zachary Kline    Zachary         Kline
# 891  ðDr Roxie Mooney, DBA        ?Dr  Roxie Mooney
# 892          Jason Bovell CPA      Jason    Bovell CPA
# 893               Kim Merritt        Kim       Merritt
#
#                                       LinkedIn profile  \
# 0                  https://www.linkedin.com/in/scaton/
# 1         https://www.linkedin.com/in/jonathan-siskin/
# 2    https://www.linkedin.com/in/mike-carpenter-656...
# 3          https://www.linkedin.com/in/benedictdsilva/
# ...

# %%
unwanted_names = ['Sam Makhlouf', 'Jeff Pabian', 'Robin Aydelotte', 'Rex Sheridan', 'Bhavesh Donga', 'Thad Horning', 'Laura Carolyn', 'Troy Hipolito', 'Stan Alhadeff BS MS MBA', 'Daniel Rice, MBA', 'Jim Fitzgerald', 'Shannon Price', 'Alicia Moore', 'Javin Rudolph III', 'Rick Hudson CISSP', 'Mike Hill', 'Adrian Bevan', 'Jeff Wagner', 'Dana Mantilia', 'Cynthia Porter, MBA', 'Christopher M. Mutti', 'Michael Morris', 'Matt Tinney', 'Alex Covarrubias', 'Matthew Whitney', 'Amanda Taylor', 'Kevin Solchenberger', 'Kristofer Pelchat', 'Angelica Figueiredo White', 'Caroline Porsiel', 'Gregory Mills', 'Heather Maxfield', 'Dennis Doyle', 'Ledon Lenzly, BS, MSBIA', 'Nathan Mumm', 'Clint Casteel', 'Darryl Berman', 'Heitor Faria (Bacula)']

# %%
df = df[~df['Name'].isin(unwanted_names)]

# %%
df.to_csv('output.csv', index=False)

# %%
df
# Out:
#                          Name First name     Last name  \
# 0                 Steve Caton      Steve         Caton
# 1             Jonathan Siskin   Jonathan        Siskin
# 2              Mike Carpenter       Mike     Carpenter
# 3             Benedict Dsilva   Benedict        Dsilva
# 4                 Laura Young      Laura         Young
# ..                        ...        ...           ...
# 888          Donald Schlising     Donald     Schlising
# 890             Zachary Kline    Zachary         Kline
# 891  ðDr Roxie Mooney, DBA        ?Dr  Roxie Mooney
# 892          Jason Bovell CPA      Jason    Bovell CPA
# 893               Kim Merritt        Kim       Merritt
#
#                                       LinkedIn profile  \
# 0                  https://www.linkedin.com/in/scaton/
# 1         https://www.linkedin.com/in/jonathan-siskin/
# 2    https://www.linkedin.com/in/mike-carpenter-656...
# 3          https://www.linkedin.com/in/benedictdsilva/
# ...

# %%
df.to_csv('output.csv', index=False)

# %%
df = pd.read_csv('output.csv')
print(df)
# Out:
#                          Name First name     Last name  \
# 0                 Steve Caton      Steve         Caton
# 1             Jonathan Siskin   Jonathan        Siskin
# 2              Mike Carpenter       Mike     Carpenter
# 3             Benedict Dsilva   Benedict        Dsilva
# 4                 Laura Young      Laura         Young
# ..                        ...        ...           ...
# 863          Donald Schlising     Donald     Schlising
# 864             Zachary Kline    Zachary         Kline
# 865  ðDr Roxie Mooney, DBA        ?Dr  Roxie Mooney
# 866          Jason Bovell CPA      Jason    Bovell CPA
# 867               Kim Merritt        Kim       Merritt
#
#                                       LinkedIn profile  \
# 0                  https://www.linkedin.com/in/scaton/
# 1         https://www.linkedin.com/in/jonathan-siskin/
# 2    https://www.linkedin.com/in/mike-carpenter-656...
# 3          https://www.linkedin.com/in/benedictdsilva/
# ...

# %%
df
# Out:
#                          Name First name     Last name  \
# 0                 Steve Caton      Steve         Caton
# 1             Jonathan Siskin   Jonathan        Siskin
# 2              Mike Carpenter       Mike     Carpenter
# 3             Benedict Dsilva   Benedict        Dsilva
# 4                 Laura Young      Laura         Young
# ..                        ...        ...           ...
# 863          Donald Schlising     Donald     Schlising
# 864             Zachary Kline    Zachary         Kline
# 865  ðDr Roxie Mooney, DBA        ?Dr  Roxie Mooney
# 866          Jason Bovell CPA      Jason    Bovell CPA
# 867               Kim Merritt        Kim       Merritt
#
#                                       LinkedIn profile  \
# 0                  https://www.linkedin.com/in/scaton/
# 1         https://www.linkedin.com/in/jonathan-siskin/
# 2    https://www.linkedin.com/in/mike-carpenter-656...
# 3          https://www.linkedin.com/in/benedictdsilva/
# ...
